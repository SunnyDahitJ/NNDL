# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyDahitJ/NNDL/blob/main/nndl_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,15,1)
z = 1/(1+ np.exp(-x))

plt.rcParams["figure.figsize"]=(5,5)
plt.plot(x,z)
plt.xlabel("input")
plt.ylabel("sigmoid")
plt.show()

# %%
# z1 = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
z1 = np.tanh(x)

plt.rcParams["figure.figsize"]=(5,5)
plt.plot(x,z1)
plt.xlabel("input")
plt.ylabel("hyperbolic")
plt.show()

# %%
z2= x

plt.rcParams["figure.figsize"]=(5,5)
plt.plot(x,z2)
plt.xlabel("input")
plt.ylabel("linear")
plt.show()

# %%
x1 =list(np.arange(-5,15,1))

def relu(arr):
  lst=[]
  for i in x1:
    if i>=0:
      lst.append(i)
    else:
      lst.append(0)
    
  return lst

# print(relu(x1))
plt.plot(x1, relu(x1))
plt.xlabel("input")
plt.ylabel("heaviside")
plt.show()

# %%
def heaviside(t):
  lst =[]
  for i in x:
    if i<=0:
      lst.append(0)
    else:
      lst.append(1)
    
  return lst


plt.plot(x, heaviside(x))
plt.xlabel("input")
plt.ylabel("relu")
plt.show()

# %%
def signum(t):
  lst =[]
  for i in x:
    if i<0:
      lst.append(-1)
    elif i==0:
      lst.append(0)
    else:
      lst.append(1)
    
  return lst


plt.plot(x, signum(x))
plt.xlabel("input")
plt.ylabel("signum")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IRIS.csv")

x_attri = df.iloc[:,:1]

z = 1/(1+np.exp(-x_attri))
plt.rcParams["figure.figsize"]=(10,10)
plt.plot(x_attri,z)
plt.xlabel("input")
plt.ylabel("sigmoid")
plt.show()

# %%
z_1 = np.tanh(x_attri)

plt.rcParams["figure.figsize"]=(10,10)
plt.plot(x_attri,z_1)
plt.xlabel("input")
plt.ylabel("hyperbolic")
plt.show()

# %%
z_2= x_attri

plt.rcParams["figure.figsize"]=(10,10)
plt.plot(x_attri,z_2)
plt.xlabel("input")
plt.ylabel("linear")
plt.show()

# %%
df = pd.read_csv("IRIS.csv")

x_attribute = list(df.sepal_length)
# x_attri
# x_attri.remove("sepal_length")
# print(x_attri)

def relu(arr):
  lst=[]
  for i in x_attribute:
    if i>=0:
      lst.append(i)
    else:
      lst.append(0)
    
  return lst

plt.rcParams["figure.figsize"]=(10,10)
plt.plot(x_attribute, relu(x_attribute))
plt.xlabel("input")
plt.ylabel("relu")
plt.show()

# %%
x_attribute = list(df.sepal_width)

def heaviside(t):
  lst =[]
  for i in x_attribute:
    if i<=0:
      lst.append(0)
    else:
      lst.append(1)
    
  return lst


plt.plot(x_attribute, heaviside(x_attribute))
plt.xlabel("input")
plt.ylabel("heaviside")
plt.show()

# %%
x_attribute = list(df.sepal_length)


def signum(t):
  lst =[]
  for i in x_attribute:
    if i<0:
      lst.append(-1)
    elif i==0:
      lst.append(0)
    else:
      lst.append(1)
    
  return lst


plt.plot(x_attribute, signum(x_attribute))
plt.xlabel("input")
plt.ylabel("signum")
plt.show()
